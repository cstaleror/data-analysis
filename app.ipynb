# %%
# Simple data usign an array
data = [50,50,47,97,49,3,53,42,26,74,82,62,37,15,70,27,36,35,48,52,63,64]
print(data)
# Out:
# [50, 50, 47, 97, 49, 3, 53, 42, 26, 74, 82, 62, 37, 15, 70, 27, 36, 35, 48, 52, 63, 64]

# %%
# Using Numpy for optimized numeric data
import numpy as np
grades = np.array(data)
print(grades)
# Out:
# [50 50 47 97 49  3 53 42 26 74 82 62 37 15 70 27 36 35 48 52 63 64]

# %%
# Comparation between
print (type(data),'x 2:', data * 2)
print('---')
print (type(grades),'x 2:', grades * 2)
# Out:
# <class 'list'> x 2: [50, 50, 47, 97, 49, 3, 53, 42, 26, 74, 82, 62, 37, 15, 70, 27, 36, 35, 48, 52, 63, 64, 50, 50, 47, 97, 49, 3, 53, 42, 26, 74, 82, 62, 37, 15, 70, 27, 36, 35, 48, 52, 63, 64]
# ---
# <class 'numpy.ndarray'> x 2: [100 100  94 194  98   6 106  84  52 148 164 124  74  30 140  54  72  70
#   96 104 126 128]

# %%
# Show array dimension (Shape)
shape = grades.shape
print(f"Dimension: {shape}")
print(f"First dimension: {shape[0]}")
# Out:
# Dimension: (22,)
# First dimension: 22

# %%
# Show data average
print(f"Average: {grades.mean()}")
# Out:
# Average: 49.18181818181818

# %%
# Define an array of study hours
study_hours = [10.0,11.5,9.0,16.0,9.25,1.0,11.5,9.0,8.5,14.5,15.5,
               13.75,9.0,8.0,15.5,8.0,9.0,6.0,10.0,12.0,12.5,12.0]

# Create a 2D array (An array of arrays)
student_data = np.array([study_hours, grades])

# Display the array
print(student_data)
print(student_data[0])

# Two arrays with 22 elements each one
print(f"Dimension: {student_data.shape}")
# Out:
# [[10.   11.5   9.   16.    9.25  1.   11.5   9.    8.5  14.5  15.5  13.75
#    9.    8.   15.5   8.    9.    6.   10.   12.   12.5  12.  ]
#  [50.   50.   47.   97.   49.    3.   53.   42.   26.   74.   82.   62.
#   37.   15.   70.   27.   36.   35.   48.   52.   63.   64.  ]]
# [10.   11.5   9.   16.    9.25  1.   11.5   9.    8.5  14.5  15.5  13.75
#   9.    8.   15.5   8.    9.    6.   10.   12.   12.5  12.  ]
# Dimension: (2, 22)

# %%
# Show the first element of the first element
print(f"First element: {student_data[0][0]}")
# Out:
# First element: 10.0

# %%
# Get the mean value of each sub-array
avg_study = student_data[0].mean()
avg_grade = student_data[1].mean()

print('Average study hours: {:.2f}\nAverage grade: {:.2f}'.format(avg_study, avg_grade))
# Out:
# Average study hours: 10.52
# Average grade: 49.18

# %% [markdown]
# ## Usign Pandas to represent 2D datasets

# %%
import pandas as pd

students_name = ['Dan', 'Joann', 'Pedro', 'Rosie', 'Ethan', 'Vicky', 'Frederic', 'Jimmie', 
                                     'Rhonda', 'Giovanni', 'Francesca', 'Rajab', 'Naiyana', 'Kian', 'Jenny',
                                     'Jakeem','Helena','Ismat','Anila','Skye','Daniel','Aisha']

# Index is automatic when it is not explicit specified
df_students = pd.DataFrame({
    'Name': students_name,
    'StudyHours': student_data[0],
    'Grade': student_data[1]
})

# %%
# Get the data for index value (Bse filtering)
df_students.loc[5]
# Out:
# Name          Vicky
# StudyHours      1.0
# Grade           3.0
# Name: 5, dtype: object

# %%
# Get a range of values by index
df_students.loc[2:6]
# Out:
#        Name  StudyHours  Grade
# 2     Pedro        9.00   47.0
# 3     Rosie       16.00   97.0
# 4     Ethan        9.25   49.0
# 5     Vicky        1.00    3.0
# 6  Frederic       11.50   53.0

# %%
# Get data in the first five rows (By array position, not index)
# Not include the last element, in this case, the 5 element
df_students.iloc[0:5]
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0

# %%
# Select specific columns from a row by its position (select ... from dataset)
df_students.iloc[0, [1, 2]]
# Out:
# StudyHours    10.0
# Grade         50.0
# Name: 0, dtype: object

# %%
# Select specific columns from a row by its column name (select Grade from dataset)
df_students.loc[0,'Grade']
# Out:
# 50.0

# %%
# Select a row usign an especific value (select * from dataset where name = 'Aisha')
df_students.loc[df_students['Name']=='Aisha']
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   64.0

# %%
# Select implicit a row usign an especific value (select * from dataset where name = 'Aisha')
df_students[df_students['Name']=='Aisha']
df_students[df_students.Name == 'Aisha']
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   64.0

# %%
# Use query method
df_students.query('Name=="Aisha"')
df_students.query('Name=="Aisha" & Grade==64') # AND operator
df_students.query('Name=="Aisha" | Name=="Dan"') # OR operator
# Out:
#      Name  StudyHours  Grade
# 0     Dan        10.0   50.0
# 21  Aisha        12.0   64.0

# %%
# Usign a dataframe from a file
path = r'c:\Users\STELLA\data-analysis\data/grades.csv'
df_students = pd.read_csv(path, delimiter=',', header='infer')

# Return first n rows (All  is by default)
df_students.head()
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0

# %%
# Verify if there are null columns in all elements
df_students.isnull()
# Out:
#      Name  StudyHours  Grade
# 0   False       False  False
# 1   False       False  False
# 2   False       False  False
# 3   False       False  False
# 4   False       False  False
# 5   False       False  False
# 6   False       False  False
# 7   False       False  False
# 8   False       False  False
# 9   False       False  False
# 10  False       False  False
# 11  False       False  False
# 12  False       False  False
# 13  False       False  False
# 14  False       False  False
# 15  False       False  False
# 16  False       False  False
# 17  False       False  False
# 18  False       False  False
# 19  False       False  False
# 20  False       False  False
# 21  False       False  False
# 22  False       False   True
# 23  False        True   True

# %%
# Show count of null in each column
df_students.isnull().sum()
# Out:
# Name          0
# StudyHours    1
# Grade         2
# dtype: int64

# %%
# Filter rows where any column is null
# 0 - Rows; 1 - Colums
df_students.loc[df_students.isnull().any(axis=1)]
# Out:
#     Name  StudyHours  Grade
# 22  Bill         8.0    NaN
# 23   Ted         NaN    NaN

# %%
# Fill query null values
df_students.StudyHours = df_students.StudyHours.fillna(
    df_students.StudyHours.mean()
)

df_students
# Out:
#          Name  StudyHours  Grade
# 0         Dan   10.000000   50.0
# 1       Joann   11.500000   50.0
# 2       Pedro    9.000000   47.0
# 3       Rosie   16.000000   97.0
# 4       Ethan    9.250000   49.0
# 5       Vicky    1.000000    3.0
# 6    Frederic   11.500000   53.0
# 7      Jimmie    9.000000   42.0
# 8      Rhonda    8.500000   26.0
# 9    Giovanni   14.500000   74.0
# 10  Francesca   15.500000   82.0
# 11      Rajab   13.750000   62.0
# 12    Naiyana    9.000000   37.0
# 13       Kian    8.000000   15.0
# 14      Jenny   15.500000   70.0
# 15     Jakeem    8.000000   27.0
# 16     Helena    9.000000   36.0
# 17      Ismat    6.000000   35.0
# 18      Anila   10.000000   48.0
# 19       Skye   12.000000   52.0
# 20     Daniel   12.500000   63.0
# 21      Aisha   12.000000   64.0
# 22       Bill    8.000000    NaN
# 23        Ted   10.413043    NaN

# %%
# Drop rows with a NULL value
# How: NUll values (All or Any)
df_students = df_students.dropna(axis=0, how='any')
df_students
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %% [markdown]
# ## Explore data in the DataFrame

# %%
# Get the avg study hours using to column name as an index
mean_study = df_students['StudyHours'].mean()

# Get the avg grade using to column name as a property (just to make the point!)
mean_grade = df_students.Grade.mean()

# Show the avg study hours and avg grade
print("Average weekly study hours: {:.2f}\nAverage grade: {:.2f}"
      .format(mean_study, mean_grade))
# Out:
# Average weekly study hours: 10.52
# Average grade: 49.18

# %%
# Get students who studied for the mean or more hours
df_students[df_students.StudyHours >= mean_study]
# Out:
#          Name  StudyHours  Grade
# 1       Joann       11.50   50.0
# 3       Rosie       16.00   97.0
# 6    Frederic       11.50   53.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 14      Jenny       15.50   70.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %%
# Manipulate returned Dataframe (Mean grade)
mean_grade = df_students[df_students.StudyHours >= mean_study].Grade.mean()
print("Average grade: {:.2f}".format(mean_grade))
# Out:
# Average grade: 66.70

# %%
# Add a new column based on other columns value
passes = pd.Series(df_students['Grade'] >= 60) # 60 is minimal approved note
df_students = pd.concat([df_students, passes.rename("Pass")], axis=1)
df_students
# Out:
#          Name  StudyHours  Grade   Pass
# 0         Dan       10.00   50.0  False
# 1       Joann       11.50   50.0  False
# 2       Pedro        9.00   47.0  False
# 3       Rosie       16.00   97.0   True
# 4       Ethan        9.25   49.0  False
# 5       Vicky        1.00    3.0  False
# 6    Frederic       11.50   53.0  False
# 7      Jimmie        9.00   42.0  False
# 8      Rhonda        8.50   26.0  False
# 9    Giovanni       14.50   74.0   True
# 10  Francesca       15.50   82.0   True
# 11      Rajab       13.75   62.0   True
# 12    Naiyana        9.00   37.0  False
# 13       Kian        8.00   15.0  False
# 14      Jenny       15.50   70.0   True
# 15     Jakeem        8.00   27.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 18      Anila       10.00   48.0  False
# 19       Skye       12.00   52.0  False
# 20     Daniel       12.50   63.0   True
# 21      Aisha       12.00   64.0   True

# %%
# Group by a column (Determinate how many students based on Pass column)
passes = df_students.groupby(df_students.Pass).Name.count()
print(f"Approved: {passes[True]}; Not approved: {passes[False]}")
# Out:
# Approved: 7; Not approved: 15

# %%
# You can add multiple columns to group
df_students.groupby(df_students.Pass)[['StudyHours', 'Grade']].mean()
# Out:
#        StudyHours      Grade
# Pass
# False    8.783333  38.000000
# True    14.250000  73.142857

# %%
# Sort data overwritting original data
df_students = df_students.sort_values('Grade', ascending=False)
df_students
# Out:
#          Name  StudyHours  Grade   Pass
# 3       Rosie       16.00   97.0   True
# 10  Francesca       15.50   82.0   True
# 9    Giovanni       14.50   74.0   True
# 14      Jenny       15.50   70.0   True
# 21      Aisha       12.00   64.0   True
# 20     Daniel       12.50   63.0   True
# 11      Rajab       13.75   62.0   True
# 6    Frederic       11.50   53.0  False
# 19       Skye       12.00   52.0  False
# 1       Joann       11.50   50.0  False
# 0         Dan       10.00   50.0  False
# 4       Ethan        9.25   49.0  False
# 18      Anila       10.00   48.0  False
# 2       Pedro        9.00   47.0  False
# 7      Jimmie        9.00   42.0  False
# 12    Naiyana        9.00   37.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 15     Jakeem        8.00   27.0  False
# 8      Rhonda        8.50   26.0  False
# 13       Kian        8.00   15.0  False
# 5       Vicky        1.00    3.0  False

# %% [markdown]
# ## Usign plots to represent charts

# %%
# %matplotlib inline

from matplotlib import pyplot as plt

# Create a bar plot of name vs grade
plt.bar(
    x=df_students.Name,
    height=df_students.Grade,
    color='orange'
)

# Customize the chart
plt.title('Student Grades')
plt.xlabel('Student')
plt.ylabel('Grade')
plt.grid(
    color='#95a5a6',
    linestyle='--',
    linewidth=2,
    axis='y',
    alpha=0.7
)
plt.xticks(rotation=90)

# Display de plot
plt.show()

# %%
# Create figure (container) explicit
fig = plt.figure(figsize=(8,3))

# Create a bar plot of name vs grade
# Create a bar plot of name vs grade
plt.bar(
    x=df_students.Name,
    height=df_students.Grade,
    color='orange'
)

# Customize the chart
plt.title('Student Grades')
plt.xlabel('Student')
plt.ylabel('Grade')
plt.grid(
    color='#95a5a6',
    linestyle='--',
    linewidth=2,
    axis='y',
    alpha=0.7
)
plt.xticks(rotation=90)


# Show the figure
plt.show()

# %%
# A figure can contain multipple subplots, each its own axis
fig, ax = plt.subplots(1, 2, figsize=(12,6))

# Create a bar plot of name vs grade on the first axis
ax[0].bar(
    x=df_students.Name,
    height=df_students.Grade,
    color='orange'
)
ax[0].set_title('Grades')
ax[0].set_xticklabels(df_students.Name, rotation=90)

# Create a pie chart of pass counts on the second axis
pass_counts = df_students['Pass'].value_counts(normalize=False)
ax[1].pie(pass_counts, labels=pass_counts)
ax[1].set_title('Passing Grades')
ax[1].legend(pass_counts.keys())

# Add a title to the Figure
fig.suptitle('Student Data')

# Show the figure
fig.show()
# Out:
# C:\Users\STELLA\AppData\Local\Temp\ipykernel_376\2709663853.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(df_students.Name, rotation=90)
# C:\Users\STELLA\AppData\Local\Temp\ipykernel_376\2709663853.py:23: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Usign pandas abstractions instead of Matplotlib API directly
df_students.plot.bar(
    x='Name',
    y='StudyHours',
    color='teal',
    figsize=(6,4),
    title='Student Grades'
)
# Out:
# <Axes: title={'center': 'Student Grades'}, xlabel='Name'>

# %% [markdown]
# ## Statical analysis
#
# ### Descriptive statics and data distripution
#
# How all the different grade values are spread across the sample (Distribution)

# %%
# Get the variable to examine
var_data = df_students['Grade']

# Create a figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.hist(var_data) # Like Gauss distribution function
# Add titles and labels
plt.title('Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the figure
fig.show()
# Out:
# C:\Users\STELLA\AppData\Local\Temp\ipykernel_376\1601217643.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Measures of central tendency
#
# The goal of this analysis is to try to find a "typical" value. Common ways to define the middle of the data include:
#
# - The mean: A simple average based on adding together all of the values in the sample set and then dividing the total by the number of samples.
# - The median: The value in the middle of the range of all of the sample values.
# - The mode: The most commonly occurring value in the sample set*

# %%
# Get the variable to examine
var = df_students['Grade']

# Get statistics
min_val = var.min()
max_val = var.max()
mean_val = var.mean()
med_val = var.median()
mod_val = var.mode()[0] # Only value

print('''
    Minimum: {:.2f}
    Mean: {:.2f}
    Median: {:.2f}
    Mode: {:.2f}
    Maximun:{:.2f}
'''.format(
    min_val,
    mean_val,
    med_val,
    mod_val,
    max_val
))

# Create a figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.hist(var)

# Add lines for the statistics
plt.axvline(x=min_val, color='gray', linestyle='dashed', linewidth=2)
plt.axvline(x=mean_val, color='cyan', linestyle='dashed', linewidth=2)
plt.axvline(x=med_val, color='red', linestyle='dashed', linewidth=2)
plt.axvline(x=mod_val, color='yellow', linestyle='dashed', linewidth=2) # type: ignore
plt.axvline(x=max_val, color='gray', linestyle='dashed', linewidth=2)

# Add titles and labels
plt.title('Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the figure
fig.show()
# Out:
#     Minimum: 3.00
#     Mean: 49.18
#     Median: 49.50
#     Mode: 50.00
#     Maximun:97.00
# C:\Users\STELLA\AppData\Local\Temp\ipykernel_376\6172006.py:44: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# You can also use a 'box-and-whiskers' plot
var = df_students['Grade']

# Create a figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.boxplot(var)

# Add titles and labels
plt.title('Data Distribution')

# Show the figure
fig.show()
# Out:
# C:\Users\STELLA\AppData\Local\Temp\ipykernel_376\1031280686.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# It´s recommend to use both plots
# Create a function that we can re-use
def show_distribution(var_data) -> None:
    from matplotlib import pyplot as plt
    
    # Get statistics
    min_val = var.min()
    max_val = var.max()
    mean_val = var.mean()
    med_val = var.median()
    mod_val = var.mode()[0]
    
    print('''
        Minimum: {:.2f}
        Mean: {:.2f}
        Median: {:.2f}
        Mode: {:.2f}
        Maximun:{:.2f}
    '''.format(
        min_val,
        mean_val,
        med_val,
        mod_val,
        max_val
    ))
    
    # Create a figure for 2 subplots (2 Rows, 1 Column)
    fig, ax = plt.subplots(2, 1, figsize=(10,4))
    
    # Plot the histogram   
    ax[0].hist(var_data)
    ax[0].set_ylabel('Frequency')
    
    # Add lines for the mean, median and mode
    ax[0].axvline(x=min_val, color='gray', linestyle='dashed', linewidth=2)
    ax[0].axvline(x=mean_val, color='cyan', linestyle='dashed', linewidth=2)
    ax[0].axvline(x=med_val, color='red', linestyle='dashed', linewidth=2)
    ax[0].axvline(x=mod_val, color='yellow', linestyle='dashed', linewidth=2) # type: ignore
    ax[0].axvline(x=max_val, color='gray', linestyle='dashed', linewidth=2)

    # Plot the boxplot
    ax[1].boxplot(var_data, vert=False)
    ax[1].set_xlabel('Value')
    
    # Add a title to the figure
    fig.suptitle('Data Distribution')
    
    # Show the figure
    fig.show()
    
# Get the variables to example
col = df_students['Grade']

# Call the function
show_distribution(col)
# Out:
#         Minimum: 3.00
#         Mean: 49.18
#         Median: 49.50
#         Mode: 50.00
#         Maximun:97.00
# C:\Users\STELLA\AppData\Local\Temp\ipykernel_376\1463495985.py:49: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Usign samples
#
# Usually, we're interested in the population, but it's simply not practical to collect all of that data. Instead, we need to try estimate what the population is like from the small amount of data (samples) that we have.
#
# If we have enough samples, we can calculate something called a **probability density function**, which estimates the distribution of grades for the full population.

# %%
def show_density(var_data):
    """Show a normal distribution"""
    from matplotlib import pyplot as plt
    
    fig = plt.figure(figsize=(10,4))
    
    # Plot density
    var_data.plot.density()
    
    # Add titles and labels
    plt.title('Data Density')
    
    # Show the mean, median and mode
    plt.axvline(x=var_data.mean(), color = 'cyan', linestyle='dashed', linewidth = 2)
    plt.axvline(x=var_data.median(), color = 'red', linestyle='dashed', linewidth = 2)
    plt.axvline(x=var_data.mode()[0], color = 'yellow', linestyle='dashed', linewidth = 2)
    
    # Show the figure
    plt.show()
    
    
# Show the density of Grade
col = df_students['Grade']
show_density(col)
